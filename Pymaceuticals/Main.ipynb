# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
# %matplotlib notebook
# %matplotlib inline

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
mousedatadf = pd.merge(study_results,mouse_metadata,on = "Mouse ID")

# Display the data table for preview
mousedatadf.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
MouseCount = len(mousedatadf["Mouse ID"].unique())
MouseCount
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
#subset =["Mouse ID","Timepoint"]
duplicates = mousedatadf.duplicated()
mousedatadf[duplicates]["Mouse ID"]
# Out:
# 137    g989
# Name: Mouse ID, dtype: object

# %%
# Optional: Get all the data for the duplicate mouse ID.
dups = mousedatadf.loc[mousedatadf["Mouse ID"] == "g989"]
dups
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# 1380     g989         30           59.082294                 1     Propriva
# 1592     g989         35           62.570880                 2     Propriva
#
#          Sex  Age_months  Weight (g)
# 107   Female          21          26
# 137   Female          21          26
# 329   Female          21          26
# 360   Female          21          26
# 620   Female          21          26
# 681   Female          21          26
# 815   Female          21          26
# 869   Female          21          26
# 950   Female          21          26
# 1111  Female          21          26
# 1195  Female          21          26
# 1380  Female          21          26
# 1592  Female          21          26

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleanmousedf = mousedatadf.loc[mousedatadf["Mouse ID"] != "g989"]
cleanmousedf.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
CleanMouseCount = len(cleanmousedf["Mouse ID"].unique())
CleanMouseCount
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
cleanmousedf.describe()
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
# mean, median, variance, standard deviation, and SEM of the tumor volume.
# Assemble the resulting series into a single summary DataFrame.
regimendf = cleanmousedf.groupby("Drug Regimen")
tumormean =regimendf["Tumor Volume (mm3)"].mean()
tumormedian=regimendf["Tumor Volume (mm3)"].median()
tumorstd=regimendf["Tumor Volume (mm3)"].std()
tumorvar=regimendf["Tumor Volume (mm3)"].var()
tumorsem=regimendf["Tumor Volume (mm3)"].sem()
summarydf = pd.DataFrame({"Mean Tumor Volume":tumormean,
                         "Median Tumor Volume":tumormedian,
                         "Tumor Volume Variance":tumorvar,
                         "Tumor Volume Std. Dev.":tumorstd,
                         "Tumor Volume Std. Err.":tumorsem})
summarydf
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# Capomulin                   4.994774                0.329346
# Ceftamin                    6.268188                0.469821
# Infubinol                   6.567243                0.492236
# Ketapril                    8.279709                0.603860
# Naftisol                    8.134708                0.596466
# Placebo                     7.821003                0.581331
# Propriva                    6.622085                0.544332
# Ramicane                    4.846308                0.320955
# Stelasyn                    7.710419                0.573111
# Zoniferol                   6.966589                0.516398

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
regimendf.agg({'Tumor Volume (mm3)' : ['mean', 'median','var','std','sem']})
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
tpcount = regimendf["Timepoint"].count()
tpcount.plot(kind = "bar",xlabel = "Drug Regimen",ylabel = "# of Observed Mouse Timepoints",color ='b',alpha = .75)
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
xaxis = np.arange(len(tpcount))
tick_locations = [value+0.4 for value in xaxis]
plt.bar(xaxis, tpcount, color='b',alpha=0.75, align="edge")
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
plt.xticks(tick_locations, tpcount.keys(), rotation="vertical")
plt.show()

# %%
# Generate a pie chart, using Pandas, showing the distribution of unique female versus male mice used in the study
cleanmousemeta = mouse_metadata.loc[mouse_metadata["Mouse ID"] != "g989"]
mfdf = cleanmousemeta.groupby("Sex")
gendercount = mfdf["Mouse ID"].count()
# Get the unique mice with their gender
#
#check1 = check.count()
#
#gendercount = mfdf['Mouse ID'].count()
# Make the pie chart
gendercount.plot(kind = 'pie',title = 'count',autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'count'}, ylabel='Mouse ID'>

# %%
# Generate a pie chart, using pyplot, showing the distribution of unique female versus male mice used in the study
mfdf2 = cleanmousedf.groupby("Sex")
# Get the unique mice with their gender

check = mfdf2['Mouse ID'].unique()

# Make the pie chart
plt.pie([len(check["Female"]),len(check["Male"])],labels = ['Female','Male'],autopct='%1.1f%%')
plt.ylabel("count")
plt.show()

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
gpmouse = cleanmousedf.groupby(["Mouse ID","Timepoint"])
maxs = gpmouse[gpmouse["Timepoint"].max()]['Tumor Volume (mm3)']
maxs
#greatesttime = cleanmousedf['Timepoint'].max()
#tvolfinal = cleanmousedf.loc[cleanmousedf['Timepoint'] == greatesttime,['Mouse ID','Tumor Volume (mm3)']]
#tvolfinal = tvolfinal.rename(columns = {"Tumor Volume (mm3)":"Final Tumor Volume (mm3)"})
# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
#mousewfinaldf = pd.merge(cleanmousedf,tvolfinal, on = "Mouse ID")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[103], line 6
#       1 # Calculate the final tumor volume of each mouse across four of the treatment regimens:
#       2 # Capomulin, Ramicane, Infubinol, and Ceftamin
#       3
#       4 # Start by getting the last (greatest) timepoint for each mouse
#       5 gpmouse = cleanmousedf.groupby(["Mouse ID","Timepoint"])
# ----> 6 maxs = gpmouse[gpmouse["Timepoint"].max()]['Tumor Volume (mm3)']
#       7 maxs
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/base.py:239, in SelectionMixin.__getitem__(self, key)
#     237     if len(self.obj.columns.intersection(key)) != len(set(key)):
#     238         bad_keys = list(set(key).difference(self.obj.columns))
# --> 239         raise KeyError(f"Columns not found: {str(bad_keys)[1:-1]}")
#     240     return self._gotitem(list(key), ndim=2)
#     242 else:
#
# KeyError: 'Columns not found: 0, 35, 5, 40, 10, 45, 15, 20, 25, 30'

# %%
ftCapomulin = mousewfinaldf.loc[mousewfinaldf['Drug Regimen'] == 'Capomulin']
ftRamicane = mousewfinaldf.loc[mousewfinaldf['Drug Regimen'] == 'Ramicane']
ftInfubinol = mousewfinaldf.loc[mousewfinaldf['Drug Regimen'] == 'Infubinol']
ftCeftamin = mousewfinaldf.loc[mousewfinaldf['Drug Regimen'] == 'Ceftamin']
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 1113     a685         40           60.567904                 2    Infubinol
# 1130     k483         40           64.138725                 3    Infubinol
# 1133     z581         40           60.053740                 3    Infubinol
# 1140     a251         40           63.095076                 1    Infubinol
# 1156     c139         40           69.428141                 2    Infubinol
# 1161     y163         40           63.620680                 2    Infubinol
# 1186     y163         45           67.685569                 3    Infubinol
# 1188     c139         45           72.226731                 2    Infubinol
# 1191     z581         45           62.754451                 3    Infubinol
# 1193     a251         45           65.525743                 1    Infubinol
# 1196     k483         45           66.196912                 3    Infubinol
# 1201     a685         45           66.083066                 3    Infubinol
# 1209     e476         45           62.435404                 1    Infubinol
# 1211     a203         45           67.973419                 2    Infubinol
# 1213     f345         45           60.918767                 1    Infubinol
#
#          Sex  Age_months  Weight (g)  Final Tumor Volume (mm3)
# 1113    Male           8          30                 66.083066
# 1130  Female          20          30                 66.196912
# 1133  Female          24          25                 62.754451
# 1140  Female          21          25                 65.525743
# 1156    Male          11          28                 72.226731
# 1161  Female          17          27                 67.685569
# 1186  Female          17          27                 67.685569
# 1188    Male          11          28                 72.226731
# 1191  Female          24          25                 62.754451
# 1193  Female          21          25                 65.525743
# 1196  Female          20          30                 66.196912
# 1201    Male           8          30                 66.083066
# 1209    Male          23          26                 62.435404
# 1211  Female          20          23                 67.973419
# 1213    Male          23          26                 60.918767

# %%
# Put treatments into a list for for loop (and later for plot labels)
Treatments = ["Capomulin","Ramicane","Infubinol","Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
Tvoldata = []

# Calculate the IQR and quantitatively determine if there are any potential outliers.
for x in range(0,4):

    # Locate the rows which contain mice on each drug and get the tumor volumes
    Tvoldata

    # add subset


    # Determine outliers using upper and lower bounds
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distribution of the tumor volume for each treatment group.
ftCapomulin = mousewfinaldf.loc[mousewfinaldf['Drug Regimen'] == 'Capomulin']
ftRamicane = mousewfinaldf.loc[mousewfinaldf['Drug Regimen'] == 'Ramicane']
ftInfubinol = mousewfinaldf.loc[mousewfinaldf['Drug Regimen'] == 'Infubinol']
ftCeftamin = mousewfinaldf.loc[mousewfinaldf['Drug Regimen'] == 'Ceftamin']

fig1, (ax1, ax2, ax3, ax4) = plt.subplots(1,4,sharey=True,sharex=True)

ax1.set_xlabel('Capomulin')
ax1.boxplot(ftCapomulin['Final Tumor Volume (mm3)'],flierprops=dict(marker='o', markerfacecolor='red', markersize=8))

ax2.set_xlabel('Ramicane')
ax2.boxplot(ftRamicane['Final Tumor Volume (mm3)'],flierprops=dict(marker='o', markerfacecolor='red', markersize=8))

ax3.set_xlabel('Infubinol')
ax3.boxplot(ftInfubinol['Final Tumor Volume (mm3)'],flierprops=dict(marker='o', markerfacecolor='red', markersize=8))

ax4.set_xlabel('Ceftamin')
ax4.boxplot(ftCeftamin['Final Tumor Volume (mm3)'],flierprops=dict(marker='o', markerfacecolor='red', markersize=8))

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
drugchoice = "Capomulin"
Capomulindf = cleanmousedf.loc[cleanmousedf["Drug Regimen"] == drugchoice]
micetreatedwithcap = Capomulindf['Mouse ID'].unique()
mousetograph = 'l509'
mousepoints = Capomulindf.loc[Capomulindf["Mouse ID"] == mousetograph]
mousepoints = mousepoints[["Timepoint","Tumor Volume (mm3)"]]
mousepoints.plot(x='Timepoint',y='Tumor Volume (mm3)',kind = 'line',xlabel = 'Tumor Volume (mm3)',ylabel = 'Timepoint (days)',title = f"{drugchoice} treatment of mouse {mousetograph}")
# Out:
# <Axes: title={'center': 'Capomulin treatment of mouse l509'}, xlabel='Tumor Volume (mm3)', ylabel='Timepoint (days)'>

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
#Capomulin
capdf = cleanmousedf.loc[cleanmousedf["Drug Regimen"] == "Capomulin"]
groupedcapdf = capdf.groupby("Mouse ID")
capavgtumor = groupedcapdf["Tumor Volume (mm3)"].mean()
mouseweight = groupedcapdf["Weight (g)"].mean()
plt.scatter(mouseweight,capavgtumor)
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
correlation = round(mouseweight.corr(capavgtumor),2)
slope, intercept, r_value, p_value, std_err = st.linregress(mouseweight, capavgtumor)
plt.plot(mouseweight, slope * mouseweight + intercept, color='red')
plt.scatter(mouseweight,capavgtumor)
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.title(f"The correlation between mouse weight and the average tumor volume is {correlation}")
plt.show()
